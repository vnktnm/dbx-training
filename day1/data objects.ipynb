# %%
# %sql
create table dev.venkat_nm.demo (id int, name string)

# %%
spark.read.csv("/Volumes/dev/naval/raw/csv/financial_dataset.csv",header=True, inferSchema=True).write.mode("overwrite").saveAsTable("dev.venkat_nm.financial")

# %%
from pandas import pd

# %%
df = spark.read.table("dev.venkat_nm.financial")
spark.sql("select * from dev.venkat_nm.financial limit 10").display()

# %%
df.filter("Branch='New York'").display()

# %%
df_1 = df.withColumnRenamed("TransactionID","transaction_id").withColumnRenamed("CustomerID","customer_id"),display()

# %%
df_1[0].display()
